# %% [markdown]
# <p style="font-size:9px;">Week 13 notebook, Apr 4, 2022; small revisions Apr 07, 2023. GB</p><hr />
# <img style="float:right;" src="images/panda-pokemon.png"/>
# <h1>Advanced Pandas Discussion.  Week 13</h1>
# <p>Teaching &amp; Learning Notes for this week.</p>

# %% [markdown]
# <ul>
#     <li>At this point in our course of study you&rsquo;ve experienced the fundamentals shared across all programming languages and delved into the &ldquo;pythonic&rdquo; ways of doing the task, with a variety of python-only shortcuts along the way.</li>
#     <li>Along the way, we integrated libraries/modules that allow scripts to communicate with the operating system, perform tasks more efficiently that you&rsquo;re expected to know on-the-job (like pandas, numpy, matplotlib, and more).</li>
# <li>Notebooks have an area that review the lesson&rsquo;s
# main points and then, increasingly as the term progressed, demonstrations of applications for more advanced programming questions.  We&rsquo;ve also seen how our computing environment grows from a single computer (our own) to networked situations (getting live data through SQL and URI connections), and ultimately to larger information ecologies, like Hadoop.  These create a useful mental framing for future programming and course topics, like statistics, ethics, visualization, and Machine Learning (ML).</li>
# <li>ML/AI/DS relies on accurate use of statistics - and all statistical analyses begin with descriptive measures (min, max) <u>and</u> require getting to know our data intimately by various what-if scenarios, extracting subsets, aggregating other sets, and then applying our informed intuition to analyses that are expected on the job, not least of which are crosstabs, pivot tables, time series, and being able to use all kinds of files/streams and encoded data.</li>
# <li>This week we can only practice some of these activities building up
# to your own work needs as you progress after this course.  Today&rsquo;s notebook is kinda intended to suggest a work flow that you can do on your first day at work.</li>
# </ul>
# <hr />
# <p style="font-family:Baskerville; color:red;font-size:22px;"><i>Parts of this notebook</i></p>
# <p>We use unfamiliar data to simulate common data activities.
#     <ol>
#         <li>&ldquo;Where to move to in Rhode Island?&rdquo; [so we get familiar with applying pandas to explore data, join datasets, make a decision based on features of importance to us]</li>
#         <li>An example of dealing with integrated data (NaN) and stats (crosstabs)</li>
#         <li>Info about file types</li>
#         <li>Time series</li>
#     </ol>
# </p>

# %% [markdown]
# <hr />
# <h1 style="color:red;">Week 13: Pandas</h1>
#     <p>Contents: a quick review of some fundamentals.</p>
# <ol>
# <li>Reading in data</li>
# <li>Getting familiar with the data (groupby, ngroups, first, get_group)</li>
# <li>agg() and basic stats</li>
# <li>using functions and lambda expressions</li>
# <li>extracting single column and condition</li>
# <li>merging and joining datasets</li>
# <li>conditions and .get()</li>
# <li>histogram hist()</li>
# <li>Joins</li>
# <li>Crosstabs and Pivot tables</li>
# <li>Structured &amp; Semi- and Unstructured Files</li>
# <li>Time Series</li>
# <li>Final exam prep</li>
# </ol>

# %% [markdown]
# <h2>A point of view of learning about our data ... </h2>
# <blockquote>
#     <p>At this point in our course, you've mastered lots of python and libraries - we're at the point where your domain expertise comes into play and we turn more to documention and other guides because of the number of code commands and your own needs outpace what can be covered usefully.  Let's review, tho, some basic steps and wrap up the rest of our content.</p>
# </blockquote>
# <p>Loading the data - here, of course, we might read a .csv or other file type, or we might poll an online resource (rdbms or webscraping).  Let's start with a very small dataset from the Census.
# </p>
# <p>Get to know the data ... column names, field data types, missing values, NaNs, rename field names, etc.  There are <u>far too many</u> commands to master in a week - review Week 11's notebooks and plan your explorations with the pandas documentation.</p>
# </p>
# <p>Once the data source seems prepped, your research area/questions come into play.  Extract subsets of the data to explore ...  In code, we might ask
# <ul>
# <li>extract a subset</li>
# <li>how many groups for that subset?</li>
# <li>who are the members of those subsets?</li>
# <li>what's the numbers of members .size()</li>
#     <li>check the subsets - head() last()</li>
#     <li>extract other subsets</li>
# </ul>

# %% [markdown]
# <hr />
# <h1>Part 1</h1>
# <p style="font-family:Baskerville; color:red;font-size:22px;">Reading in some data</p>
# <p>You can import comma-separated values in a txt file, too, replacing \t with a comma; or use the sep="" command, e.g., <code>df = pd.read_csv("mysource.txt", sep=" ")</code></p>
# <p>Remember, there&rsquo;s also <code>read_excel()</code>, <code>json.loads()</code> [returns a dictionary] and <code>json.load() [to pass to var]</code>, <code>read_csv()</code>, each with a number of parameters for handling NaNs, missing values, headers.</p>
# <hr />
# <p style="font-family:Baskerville; color:red;font-size:22px;"><i>A Demonstration Project used this notebook:</i></p>
# <a href="images/rhode-island-county-map.png" target="new"><img style="float:left; width:220px;" src="images/rhode-island-county-map.png"></a><p>Say you&rsquo;re faced with a decision and want to use data to help select your new home.  Where to live in Rhode Island?  Explore data about the state from official records to get to know the area of our study and then ask questions that allow us to make decisions.</p>
# <p>Notice there are a couple of levels of granularity: the entire state, the county, and the individual cities (all five of them) and the towns.</p>
# <img style="float:right; width:150px;" src="images/goatisland.png"/><br />
# <p style="font-size:9px; font-family:'Avenir Next', sans-serif;">The map shows the towns and cities of the Ocean State (including prof. Benoît&rsquo;s hometown of Scituate); on the right is an image of Goat Island lighthouse, now a BnB you can rent on a small island in Newport Harbor. Recommended!</p>

# %%
import pandas as pd

df = pd.read_csv('ri_data.txt')
df.head()
# Out:
#             Town  Household  Family  PerCap      County
# 0     Barrington     125431  147849   65777     Newport
# 1        Bristol      72610   95422   36960     Newport
# 2   Burrillville      84680   99019   35127  Providence
# 3  Central Falls      32982   34623   15519  Providence
# 4    Charlestown      78209   92246   44597       South

# %% [markdown]
# <hr /><p style="font-family:Baskerville; color:red;font-size:22px;"><i>Becoming familiar with the file</i></p>
# <p>Given this small set, I want to group by county and explore...  How many sets will I find?  Who are the members thereof? </p>

# %%
df_county = df.groupby('County')
print("Number of groups: ", df_county.ngroups)
# Out:
# Number of groups:  4

# %%
print("Groups: ", df_county.groups)
print("-"*40)
# tells us the # of towns in each county
print("Towns per County: ", df_county.size())
# Out:
# Groups:  {'Kent': [5, 6, 8, 10, 34, 35, 36], 'Newport': [0, 1, 14, 17, 18, 21, 26, 32, 33], 'Providence': [2, 3, 7, 9, 11, 12, 15, 16, 23, 24, 25, 27, 29, 30, 38], 'South': [4, 13, 19, 20, 22, 28, 31, 37]}
# ----------------------------------------
# Towns per County:  County
# Kent           7
# Newport        9
# Providence    15
# South          8
# dtype: int64

# %%
df_county.first()
# Out:
#                     Town  Household  Family  PerCap
# County
# Kent            Coventry      73392   91004   37216
# Newport       Barrington     125431  147849   65777
# Providence  Burrillville      84680   99019   35127
# South        Charlestown      78209   92246   44597

# %%
df_newport = df_county.get_group('Newport')
df_newport
# Out:
#               Town  Household  Family  PerCap
# 0       Barrington     125431  147849   65777
# 1          Bristol      72610   95422   36960
# 14       Jamestown     111110  125375   66010
# 17  Little Compton      89353  100938   59999
# 18      Middletown      73609   87442   41675
# 21         Newport      67102   95078   44386
# 26      Portsmouth     100453  122738   55858
# 32        Tiverton      75295   89250   40365
# 33          Warren      59926   94093   37303

# %% [markdown]
# <hr /><p style="font-family:Baskerville; color:red;font-size:22px;"><i>Check out some basic stats...</i></p>

# %%
# great.  We have our subset ... let's get some basic
# stats ...
df_newport.groupby('Town').Household.agg(['min','max','mean'])
# Out:
#                    min     max    mean
# Town
# Barrington      125431  125431  125431
# Bristol          72610   72610   72610
# Jamestown       111110  111110  111110
# Little Compton   89353   89353   89353
# Middletown       73609   73609   73609
# Newport          67102   67102   67102
# Portsmouth      100453  100453  100453
# Tiverton         75295   75295   75295
# Warren           59926   59926   59926

# %% [markdown]
# <p>In the above case, it turns out own data already is mean/max/min... so let's just see the min/max</p>

# %%
df.groupby('Town').Household.agg(
    town_max=('max'),town_min=('min'))
# Out:
#                   town_max  town_min
# Town
# Barrington          125431    125431
# Bristol              72610     72610
# Burrillville         84680     84680
# Central Falls        32982     32982
# Charlestown          78209     78209
# Coventry             73392     73392
# Cranston             72017     72017
# Cumberland           91726     91726
# East Greenwich      114147    114147
# East Providence      59142     59142
# Exeter               84919     84919
# Foster               89844     89844
# Glocester            89391     89391
# Hopkinton            90134     90134
# Jamestown           111110    111110
# Johnston             65125     65125
# Lincoln              81045     81045
# Little Compton       89353     89353
# Middletown           73609     73609
# Narragansett         86920     86920
# New Shoreham         59423     59423
# Newport              67102     67102
# North Kingstown      91796     91796
# North Providence     57135     57135
# North Smithfield     78617     78617
# Pawtucket            50476     50476
# Portsmouth          100453    100453
# Providence           45610     45610
# Richmond             95391     95391
# Scituate             96179     96179
# Smithfield           85337     85337
# South Kingstown      89917     89917
# Tiverton             75295     75295
# Warren               59926     59926
# Warwick              73757     73757
# West Greenwich      119688    119688
# West Warwick         55927     55927
# Westerly             70784     70784
# Woonsocket           42595     42595

# %% [markdown]
# <hr /><p style="font-family:Baskerville; color:red;font-size:22px;"><i>Functions or Lambda expressions for conditions: a combination of the stringing of methods + lambda...</i></p>

# %%
# we're looking for towns with household income
# greater than 80000
def town_income(x):
    i = x.mean()
    return True if i > 80000 else False

df_x = df.groupby('Town').Household.agg(['mean',town_income])
# this can be written with a lambda ... 
# replace 'town_income' with lambda x : 
# True if x.mean() > 80000 else False

# %%
df_wealthy = df.groupby('Town').Household.agg(
    ['mean',lambda x : True if x.mean() > 80000 else False])
df_wealthy
# Out:
#                     mean  <lambda_0>
# Town
# Barrington        125431        True
# Bristol            72610       False
# Burrillville       84680        True
# Central Falls      32982       False
# Charlestown        78209       False
# Coventry           73392       False
# Cranston           72017       False
# Cumberland         91726        True
# East Greenwich    114147        True
# East Providence    59142       False
# Exeter             84919        True
# Foster             89844        True
# Glocester          89391        True
# Hopkinton          90134        True
# Jamestown         111110        True
# Johnston           65125       False
# Lincoln            81045        True
# Little Compton     89353        True
# Middletown         73609       False
# Narragansett       86920        True
# New Shoreham       59423       False
# Newport            67102       False
# North Kingstown    91796        True
# North Providence   57135       False
# North Smithfield   78617       False
# Pawtucket          50476       False
# Portsmouth        100453        True
# Providence         45610       False
# Richmond           95391        True
# Scituate           96179        True
# Smithfield         85337        True
# South Kingstown    89917        True
# Tiverton           75295       False
# Warren             59926       False
# Warwick            73757       False
# West Greenwich    119688        True
# West Warwick       55927       False
# Westerly           70784       False
# Woonsocket         42595       False

# %%
df_compare = df.loc[:, ['Town','Household', 'PerCap']]
df_compare.groupby(['Town','PerCap']).mean()
# Out:
#                          Household
# Town             PerCap
# Barrington       65777      125431
# Bristol          36960       72610
# Burrillville     35127       84680
# Central Falls    15519       32982
# Charlestown      44597       78209
# Coventry         37216       73392
# Cranston         33974       72017
# Cumberland       43603       91726
# East Greenwich   62337      114147
# East Providence  33091       59142
# Exeter           40802       84919
# Foster           36839       89844
# Glocester        38174       89391
# Hopkinton        40169       90134
# Jamestown        66010      111110
# Johnston         35307       65125
# Lincoln          43573       81045
# Little Compton   59999       89353
# Middletown       41675       73609
# Narragansett     49277       86920
# New Shoreham     36812       59423
# Newport          44386       67102
# North Kingstown  47120       91796
# North Providence 34495       57135
# North Smithfield 39523       78617
# Pawtucket        27799       50476
# Portsmouth       55858      100453
# Providence       26560       45610
# Richmond         40232       95391
# Scituate         47911       96179
# Smithfield       38514       85337
# South Kingstown  38927       89917
# Tiverton         40365       75295
# Warren           37303       59926
# Warwick          39653       73757
# West Greenwich   46008      119688
# West Warwick     32176       55927
# Westerly         40999       70784
# Woonsocket       24957       42595

# %% [markdown]
# <hr />
# <p style="font-family:Baskerville; color:red;font-size:22px;"><i>Zeroing in ...</i>.</p><p>After our initial review of the data we have a sense of what we might want to focus on ... here, say we want a single locale, Newport.</p>

# %%
df_compare.loc[df_compare['Town'] == 'Newport']
# Out:
#        Town  Household  PerCap
# 21  Newport      67102   44386

# %% [markdown]
# <hr />
# <p style="font-family:Baskerville; color:red;font-size:32px;line-height: 36px;"><i>
#     Merging and Joining Datasets</i></p>
# <p>Note that it&rsquo;s common to integrate several datasets to bolster our own data - from professional &amp; industrial standards or our own long-term studies for longitudinal data or more dimensions.</p>
# <p>Scenario: you have 2+ datasets to merge and to explore because you want to <i>ask questions of the data</i>, such as what's the most educated and well-off <i>towns</i> (as our unit of analysis) of the state to move to? ... Here we have our RI data and added: the original income and now one about education rates.</p>

# %%
df_income = pd.read_csv('ri_data.txt')
df_educ = pd.read_csv('ri_edu.txt')

# merge them and see what happens...

# %%
#pd.merge(df_income, df_educ)
# without a common column name, the merge will fail ... 
# in which case you a join option (below)
df_merged = pd.merge(df_income, df_educ, on='Town')
df_merged
# Out:
#                 Town  Household  Family  PerCap      County  Over25  \
# 0         Barrington     125431  147849   65777     Newport   11141
# 1            Bristol      72610   95422   36960     Newport   14672
# 2       Burrillville      84680   99019   35127  Providence   11808
# 3      Central Falls      32982   34623   15519  Providence   11636
# 4        Charlestown      78209   92246   44597       South    5852
# 5           Coventry      73392   91004   37216        Kent   25176
# 6           Cranston      72017   88700   33974        Kent   57873
# 7         Cumberland      91726  109169   43603  Providence   25176
# 8     East Greenwich     114147  153475   62337        Kent    9030
# 9    East Providence      59142   78400   33091  Providence   35274
# 10            Exeter      84919  110929   40802        Kent    4552
# 11            Foster      89844  104679   36839  Providence    3461
# 12         Glocester      89391  101250   38174  Providence    7386
# 13         Hopkinton      90134   99545   40169       South    5836
# 14         Jamestown     111110  125375   66010     Newport    4189
# 15          Johnston      65125   91760   35307  Providence   22222
# 16           Lincoln      81045  107146   43573  Providence   15197
# 17    Little Compton      89353  100938   59999     Newport    2844
# 18        Middletown      73609   87442   41675     Newport   11971
# 19      Narragansett      86920  131548   49277       South   10337
# 20      New Shoreham      59423   66071   36812       South     718
# 21           Newport      67102   95078   44386     Newport   17143
# 22   North Kingstown      91796  113950   47120       South   18735
# 23  North Providence      57135   78703   34495  Providence   24209
# 24  North Smithfield      78617  100488   39523  Providence    9262
# 25         Pawtucket      50476   60984   27799  Providence   50877
# 26        Portsmouth     100453  122738   55858     Newport   12564
# 27        Providence      45610   53659   26560  Providence  108898
# 28          Richmond      95391  108148   40232       South    5424
# 29          Scituate      96179  112024   47911  Providence    7875
# 30        Smithfield      85337  103711   38514  Providence   14588
# 31   South Kingstown      89917  112978   38927       South   18169
# 32          Tiverton      75295   89250   40365     Newport   12154
# 33            Warren      59926   94093   37303     Newport    8323
# 34           Warwick      73757   92368   39653        Kent   61174
# 35    West Greenwich     119688  120331   46008        Kent    4632
# 36      West Warwick      55927   74649   32176        Kent   21018
# 37          Westerly      70784   97107   40999       South   16861
# 38        Woonsocket      42595   54129   24957  Providence   28943
#
#     HSGradCollege    BA
# 0            97.1  69.1
# 1            87.5  41.1
# 2            90.1  29.0
# 3            64.9   8.1
# 4            94.5  38.0
# 5            91.2  27.5
# 6            89.9  33.2
# 7            90.1  38.9
# 8            96.4  62.6
# 9            85.8  28.6
# 10           91.7  48.6
# 11           95.8  34.7
# 12           94.7  32.2
# 13           95.7  30.6
# 14           97.2  64.6
# 15           89.5  23.8
# 16           91.5  41.1
# 17           97.4  52.9
# 18           93.5  45.6
# 19           97.5  56.7
# 20           97.4  36.1
# 21           94.1  52.8
# 22           95.4  51.4
# 23           91.2  30.0
# 24           91.3  31.3
# 25           81.3  21.8
# 26           94.9  52.3
# 27           81.6  30.1
# 28           96.3  35.8
# 29           95.9  36.6
# 30           93.0  36.3
# 31           95.6  55.7
# 32           91.5  32.6
# 33           88.7  36.2
# 34           92.5  33.8
# 35           95.6  46.1
# 36           89.8  23.3
# 37           92.4  34.8
# 38           81.8  17.8

# %% [markdown]
# <hr />
# <p style="font-family:Baskerville; color:red;font-size:22px;"><i>As before use conditions, pyaing attention to the order of operations ( ).</i></p>

# %%
df_merged[(df_merged['HSGradCollege'] > 90) & (df_merged['BA'] > 50)]
# Out:
#                Town  Household  Family  PerCap   County  Over25  \
# 0        Barrington     125431  147849   65777  Newport   11141
# 8    East Greenwich     114147  153475   62337     Kent    9030
# 14        Jamestown     111110  125375   66010  Newport    4189
# 17   Little Compton      89353  100938   59999  Newport    2844
# 19     Narragansett      86920  131548   49277    South   10337
# 21          Newport      67102   95078   44386  Newport   17143
# 22  North Kingstown      91796  113950   47120    South   18735
# 26       Portsmouth     100453  122738   55858  Newport   12564
# 31  South Kingstown      89917  112978   38927    South   18169
#
#     HSGradCollege    BA
# 0            97.1  69.1
# 8            96.4  62.6
# 14           97.2  64.6
# 17           97.4  52.9
# 19           97.5  56.7
# 21           94.1  52.8
# 22           95.4  51.4
# 26           94.9  52.3
# 31           95.6  55.7

# %%
df_merged.get(['Town','BA'])
# Out:
#                 Town    BA
# 0         Barrington  69.1
# 1            Bristol  41.1
# 2       Burrillville  29.0
# 3      Central Falls   8.1
# 4        Charlestown  38.0
# 5           Coventry  27.5
# 6           Cranston  33.2
# 7         Cumberland  38.9
# 8     East Greenwich  62.6
# 9    East Providence  28.6
# 10            Exeter  48.6
# 11            Foster  34.7
# 12         Glocester  32.2
# 13         Hopkinton  30.6
# 14         Jamestown  64.6
# 15          Johnston  23.8
# 16           Lincoln  41.1
# 17    Little Compton  52.9
# 18        Middletown  45.6
# 19      Narragansett  56.7
# 20      New Shoreham  36.1
# 21           Newport  52.8
# 22   North Kingstown  51.4
# 23  North Providence  30.0
# 24  North Smithfield  31.3
# 25         Pawtucket  21.8
# 26        Portsmouth  52.3
# 27        Providence  30.1
# 28          Richmond  35.8
# 29          Scituate  36.6
# 30        Smithfield  36.3
# 31   South Kingstown  55.7
# 32          Tiverton  32.6
# 33            Warren  36.2
# 34           Warwick  33.8
# 35    West Greenwich  46.1
# 36      West Warwick  23.3
# 37          Westerly  34.8
# 38        Woonsocket  17.8

# %% [markdown]
# <hr /><p style="font-family:Baskerville; color:red;font-size:22px;"><i>Visualize the data.</i></p>

# %%
df_merged.hist()
# Out:
# --------------------------------------------------------------------------
# AttributeError                           Traceback (most recent call last)
# <ipython-input-19-8c6f075ba2f8> in <module>
# ----> 1 df_merged.hist()
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/plotting/_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     209     """
#     210     plot_backend = _get_plot_backend(backend)
# --> 211     return plot_backend.hist_frame(
#     212         data,
#     213         column=column,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/plotting/_matplotlib/hist.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, legend, **kwds)
#     415         raise ValueError("hist method requires numerical columns, nothing to plot.")
#     416
# --> 417     fig, axes = _subplots(
#     418         naxes=naxes,
#     419         ax=ax,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/plotting/_matplotlib/tools.py in _subplots(naxes, sharex, sharey, squeeze, subplot_kw, ax, layout, layout_type, **fig_kw)
#     256             ax.set_visible(False)
#     257
# --> 258     _handle_shared_axes(axarr, nplots, naxes, nrows, ncols, sharex, sharey)
#     259
#     260     if squeeze:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/plotting/_matplotlib/tools.py in _handle_shared_axes(axarr, nplots, naxes, nrows, ncols, sharex, sharey)
#     329                 # off as we only have labels in the first column and we always
#     330                 # have a subplot there, we can skip the layout test
# --> 331                 if ax.is_first_col():
#     332                     continue
#     333                 if sharey or len(ax.get_shared_y_axes().get_siblings(ax)) > 1:
#
# AttributeError: 'Axes' object has no attribute 'is_first_col'

# %% [markdown]
# <hr />
# <h1>Part 2</h1>
# <p style="font-family:Baskerville; color:red;font-size:32px;line-height: 36px;"><i>Merging with different column names</i></p>
# <p>Note that if there are different column names in the
# files you&rsquo;ll have to tell pandas which column in each
# &ldquo;left&rdquo; and &ldquo;right&rdquo; to join on ...</p>
# <p>
#     <pre>pd.merge(df_income, df_educ,
#         left_on = 'Region',
#         right_on = 'Town
#         )</pre>
# </p>
#     <h2>NaN</h2><p>See https://pandas.pydata.org/docs/user_guide/missing_data.html</p>

# %% [markdown]
# <img src="images/joins.png"/>

# %% [markdown]
# <hr />
# <p>More about joins...  as you probably know
#     <ul>
#         <li>inner: the default join type in Pandas merge() function and it produces records that have matching values in both DataFrames</li>
# <li>left: produces all records from the left DataFrame and the matched records from the right DataFrame</li>
# <li>right: produces all records from the right DataFrame and the matched records from the left DataFrame</li>
#         <li>outer: produces all records when there is a match in either left or right DataFrame</li>
#         </ul>
# <p><a href="https://towardsdatascience.com/all-the-pandas-merge-you-should-know-for-combining-datasets-526b9ecaf184" target="new">https://towardsdatascience.com/all-the-pandas-merge-you-should-know-for-combining-datasets-526b9ecaf184</a></p>

# %% [markdown]
# <hr />
# <p style="font-family:Baskerville; color:red;font-size:32px;line-height: 36px;"><i>Crosstabs</i></p>
# <p>The pandas crosstab function builds a cross-tabulation table that can show the frequency with which certain groups of data appear. </p>
# <p>Using a well-known dataset from UCI Machine Learning Repository [https://archive-beta.ics.uci.edu/]</p>
# <p>For more about crosstabs versus pivot, see <a href="https://chenzheruc.github.io/tutorial/tutorial_crosstabpivot.htm" target="new">https://chenzheruc.github.io/tutorial/tutorial_crosstabpivot.htm</a></p>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

df = pd.read_excel("sales-funnel.xlsx")
df.head()
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
# 4          CPU         2  65000        won

# %% [markdown]
# <p style="font-family: Baskerville; color:red; font-size:18px;"><i>Definition</i></p>
# <blockquote>
#     <p>A contingency table is a data aggregating only by counting item.
# People (and pandas) use the term "pivot" (formerly a MS-copyrighted term!)</p>
# <p>A pivot table is a table of grouped values that aggregates the individual items of a more extensive table (such as from a database, spreadsheet, or business intelligence program) within one or more discrete categories. This summary might include sums, averages, or other statistics, which the pivot table groups together using a chosen aggregation function applied to the grouped values.</p>
#     <p>The choice of field(s) to group depend on our task - what fields and groups interest us.</p>
#     </blockquote>

# %%
pd.pivot_table(df,index=["Name","Rep","Manager"])
# Out:
#                                                           Account   Price  \
# Name                         Rep           Manager
# Barton LLC                   John Smith    Debra Henley    740150   35000
# Fritsch, Russel and Anderson Craig Booker  Debra Henley    737550   35000
# Herman LLC                   Cedric Moss   Fred Anderson   141962   65000
# Jerde-Hilpert                John Smith    Debra Henley    412290    5000
# Kassulke, Ondricka and Metz  Wendy Yule    Fred Anderson   307599    7000
# Keeling LLC                  Wendy Yule    Fred Anderson   688981  100000
# Kiehn-Spinka                 Daniel Hilton Debra Henley    146832   65000
# Koepp Ltd                    Wendy Yule    Fred Anderson   729833   35000
# Kulas Inc                    Daniel Hilton Debra Henley    218895   25000
# Purdy-Kunde                  Cedric Moss   Fred Anderson   163416   30000
# Stokes LLC                   Cedric Moss   Fred Anderson   239344    7500
# Trantow-Barrows              Craig Booker  Debra Henley    714466   15000
#
#                                                           Quantity
# Name                         Rep           Manager
# Barton LLC                   John Smith    Debra Henley   1.000000
# Fritsch, Russel and Anderson Craig Booker  Debra Henley   1.000000
# Herman LLC                   Cedric Moss   Fred Anderson  2.000000
# Jerde-Hilpert                John Smith    Debra Henley   2.000000
# Kassulke, Ondricka and Metz  Wendy Yule    Fred Anderson  3.000000
# Keeling LLC                  Wendy Yule    Fred Anderson  5.000000
# Kiehn-Spinka                 Daniel Hilton Debra Henley   2.000000
# Koepp Ltd                    Wendy Yule    Fred Anderson  2.000000
# Kulas Inc                    Daniel Hilton Debra Henley   1.500000
# Purdy-Kunde                  Cedric Moss   Fred Anderson  1.000000
# Stokes LLC                   Cedric Moss   Fred Anderson  1.000000
# Trantow-Barrows              Craig Booker  Debra Henley   1.333333

# %% [markdown]
# <hr/>
# <p>Imagine the above data table held a lot more!  It'd be useless to try to find any datum of significance; Grouping data by some larger concept, like job title, city/town, patient group, etc., make it easier for us to <i>use</i> the data.</p>

# %%
pd.pivot_table(df,index=["Manager","Rep"],values=["Price"])
# Out:
#                                     Price
# Manager       Rep
# Debra Henley  Craig Booker   20000.000000
#               Daniel Hilton  38333.333333
#               John Smith     20000.000000
# Fred Anderson Cedric Moss    27500.000000
#               Wendy Yule     44250.000000

# %%
pd.pivot_table(df,index=["Manager","Rep"],values=["Price"],aggfunc=np.sum)
# Out:
#                               Price
# Manager       Rep
# Debra Henley  Craig Booker    80000
#               Daniel Hilton  115000
#               John Smith      40000
# Fred Anderson Cedric Moss    110000
#               Wendy Yule     177000

# %%
# DataFrames like SQL: query
pd.pivot_table(df,index=["Manager","Rep"],values=["Price"],aggfunc=np.sum)
# Out:
#                               Price
# Manager       Rep
# Debra Henley  Craig Booker    80000
#               Daniel Hilton  115000
#               John Smith      40000
# Fred Anderson Cedric Moss    110000
#               Wendy Yule     177000

# %%
pd.crosstab(df.Rep, df.Price)
# Out:
# Price          5000    7000    10000   30000   35000   40000   65000   100000
# Rep
# Cedric Moss         1       0       1       1       0       0       1       0
# Craig Booker        1       0       1       1       1       0       0       0
# Daniel Hilton       0       0       1       0       0       1       1       0
# John Smith          1       0       0       0       1       0       0       0
# Wendy Yule          1       1       0       0       0       0       1       1

# %%
pd.crosstab(df.Rep, df.Price, margins=True, margins_name="Total")
# Out:
# Price          5000  7000  10000  30000  35000  40000  65000  100000  Total
# Rep
# Cedric Moss       1     0      1      1      0      0      1       0      4
# Craig Booker      1     0      1      1      1      0      0       0      4
# Daniel Hilton     0     0      1      0      0      1      1       0      3
# John Smith        1     0      0      0      1      0      0       0      2
# Wendy Yule        1     1      0      0      0      0      1       1      4
# Total             4     1      3      2      2      1      3       1     17

# %%
sns.heatmap(pd.crosstab([df.Product, df.Price], [df.Rep, df.Quantity]),
            cmap="YlGnBu", annot=True, cbar=False)
# Out:
# <AxesSubplot:xlabel='Rep-Quantity', ylabel='Product-Price'>

# %% [markdown]
# <hr />
# <h1>Part 3</h1>
# <hr />
# <p style="font-family:Baskerville; color:red;font-size:32px;line-height: 36px;"><i>Files: Structured, Semi-Structured, Unstructured Files, and some new efficient, special-purpose ones</i></p>
# <p>A brief note (for Wk 14) about files.  A common division is <u>structured</u> data and <u>unstructured</u>.  Some folk include <u>semi-structured</u>.
# </p>
# <ol><li>
#     <b>Structured</b>: usually something from an application, such as SQL, where the application itself facilitates creating data tables, conforming to a standard, that's more efficient for storage and retrieval.</li>
#     <li><b>Unstructured</b>: is just a text file - the stream of letters or characters in a flat file, usually casually called .txt files.  Here we might include non-relational (NoSQL) databases.</li>
#     <li><b>Semi-structured</b>: are text files where the structure of the file and the data are all just text.  Most common examples are .json and sgml-derivatives (.html, .svg, .xml, etc.): the metadata is used to extract meaningful subsets.</li>
# </ol>
# <p>Semi-structured files typically conform to some industry-specific practice and descriptive standards: for instance, XBRL (Extensible Business REporting Language), VRA4 (Visual Resources Descriptors, 4th ed.), MathML (Math Modeling Language), phyloXML (phylogenetic networks in genomics) and endless others.</p>
# <hr />
# <p>Notice there are efficiencies that can be build into data files (similar to the compressions and techniques used in binary/media files)  (thanks, Ray) - such as Apache Parquet (Databricks) project. [<a href="https://www.databricks.com/glossary/what-is-parquet" target="new">Apache Parquet homepage</a>]</p>
# <p></p>
# <p style="font-family:Baskerville; color:red;font-size:18px;"><i>Learn about your files</i></p>
# <p>... imagine you&rsquo;ve been given a data set from some
#     area of work that&rsquo;s entirely outside your experience - like Variant Call Format (.vcf)  For our final exam, you&rsquo;ll want to know about <strong>VCF File</strong> <a href="https://en.wikipedia.org/wiki/Variant_Call_Format" target="new">a genomics file.</a></p>

# %% [markdown]
# <hr />
# <h1>Part 4</h1>
# <hr />
# <p style="font-family:Baskerville; color:red;font-size:32px;line-height: 36px;"><i>Time Series</i></p>
# <p>Time series analyses typically reveal trends, irregularities, time-dependent cycles and seasonality.</p>
# <p>NB: There are also models popular <u>depending on the work domain</u> e.g., ARIMA (Auto-Regressive Integrated Moving Average) [to predict errors]; Moving Average [helps identify random noise and plotting to smooth out noise], techniques in Data Cleansing such as MCAR (Missing completely at random), MAR (missing at random), closest-fit, imputation using association rules, hidden Markov models and others.</p>
# <p>Optionally, please visit the Data Cleaning presentation []</p>
# <p></p>
# <p>Naturally you&rsquo;ll have to work with, format, and manipulate date/time data.</p>
# <p>Check out <a href="https://www.machinelearningplus.com/time-series/time-series-analysis-python/" target="new"> for a nice demo</a>.</p>

# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
from pandas.plotting import autocorrelation_plot
from pandas import DataFrame
from statsmodels.tsa.arima_model import ARIMA

def parser(x):
    return datetime.strptime('190'+x, '%Y-%m')

# NOTE: the above strptime takes (string, format)
# but has been deprecated. Use pd.to_datetime().
# see https://pandas.pydata.org/docs/reference/api/pandas.Timestamp.strptime.html

series = read_csv('shampoo.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser = parser)
print(series.head())
# Out:
# /var/folders/5d/71r9310j2ws92zzdr2rf4rg00000gn/T/ipykernel_2468/83638773.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime
# Month
# 1901-01-01    266.0
# 1901-02-01    145.9
# 1901-03-01    183.1
# 1901-04-01    119.3
# 1901-05-01    180.3
# Name: Sales, dtype: float64

# %%
series.plot()
pyplot.show()

# %%
autocorrelation_plot(series)
pyplot.show()

# %% [markdown]
# <h1>Next week: Presentations</h1>

# %% [markdown]
# <hr />
# <h1 style="font-family:'Avenir Next',Arial; color: maroon;">As you progress with Python ... </h1>
# <p style="font-family:'Avenir Next',Arial;">Please note that python is ever evolving.  The current release (Nov, 2022) is 3.11.x.  There are <u>many</u> significant changes between 3.11 and earlier releases, some of which touch on encoding defaults, lots of command syntax changes, and <strong>important</strong> to note that many popular libraries have not yet been ported to work with 3.11.</p>
# <hr />
# <p style="font-family:'Avenir Next',Arial;">The best way to proceed is to define for yourself a project that really interests you.  That&rsquo;ll require (force) you to work more closely with the OS, python, and address conflicts between libraries (e.g., can&rsquo;t use PIL and pillow; tkinter and ttkiner different syntaxes in GUI design, and more.  Code isn&rsquo;t ever finished - it&rsquo;s only delivered!</p>
# <h1 style="color:green;">Best wishes from all the instructors, TAs, reader, coördinator and more for great fun, success, and continued exploration of coding!</h1> <p>Apologies for missing other folk.</p>
# <table>
#     <tr>
#         <td><img width="100px;" src="images/matt.jpg"><br />Matt</td>
#         <td><img width="100px;" src="images/paul.jpg"><br />Paul</td>
#         <td><img width="100px;" src="images/sridevi.jpeg"><br />Sridevi</td>
#         <td><img width="100px;" src="images/mumin.jpeg"><br />Mumin</td>
#         <td><img width="100px;" src="images/gb2.jpg"><br />GB</td>
#     </tr>
#     </table>
